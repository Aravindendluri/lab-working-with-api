# %%
# AS the lab instructions were not enough to complete it we are trying new stuff with api
NBA = response1 = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
NBA.status_code
# we are not properly authenticated
# Out:
# 401

# %%
# getting APIs for earthquakes in USA
from pandas.io.json import json_normalize
response2 = requests.get('https://earthquake.usgs.gov/fdsnws/event/1/query?format=geojson')
out = response2.json()
earthquake_data = json_normalize(out['features'])
earthquake_data
# Out:
# /var/folders/_n/wzm_vp5d0rd989db9nyndr8m0000gp/T/ipykernel_32081/3792849529.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   earthquake_data = json_normalize(out['features'])
#          type            id  properties.mag                properties.place  \
# 0     Feature    nc73765090            0.83       5km NW of The Geysers, CA
# 1     Feature  ak022a2dz7on            1.40     47 km NNW of Valdez, Alaska
# 2     Feature    nn00844348            0.30         30 km S of Mina, Nevada
# 3     Feature    ci40076895            1.05            16km SW of Oasis, CA
# 4     Feature    ci40076887            0.80            15km SW of Oasis, CA
# ...       ...           ...             ...                             ...
# 8825  Feature    nn00842482            0.20     43 km WSW of Beatty, Nevada
# 8826  Feature    ci40299752            0.83  12km NNE of Ocotillo Wells, CA
# 8827  Feature    ci40299744            0.30             10km SW of Anza, CA
# 8828  Feature    uu60504982            2.00                            Utah
# 8829  Feature  ak0228orwnxa            1.20   6 km W of Eagle River, Alaska
#
#       properties.time  properties.updated properties.tz  \
# 0       1659875119900       1659875216195          None
# 1       1659875016393       1659875135720          None
# 2       1659874892338       1659875189636          None
# 3       1659874633270       1659874842365          None
# 4       1659874608080       1659874819363          None
# ...               ...                 ...           ...
# 8825    1657283775741       1657326779771          None
# 8826    1657283760000       1657326156797          None
# 8827    1657283674070       1657325899761          None
# 8828    1657283553130       1657290959830          None
# 8829    1657283525420       1657283627822          None
#
#                                          properties.url  \
# 0     https://earthquake.usgs.gov/earthquakes/eventp...
# 1     https://earthquake.usgs.gov/earthquakes/eventp...
# 2     https://earthquake.usgs.gov/earthquakes/eventp...
# 3     https://earthquake.usgs.gov/earthquakes/eventp...
# 4     https://earthquake.usgs.gov/earthquakes/eventp...
# ...                                                 ...
# 8825  https://earthquake.usgs.gov/earthquakes/eventp...
# 8826  https://earthquake.usgs.gov/earthquakes/eventp...
# 8827  https://earthquake.usgs.gov/earthquakes/eventp...
# 8828  https://earthquake.usgs.gov/earthquakes/eventp...
# 8829  https://earthquake.usgs.gov/earthquakes/eventp...
#
#                                       properties.detail  properties.felt  ...  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# ...                                                 ...              ...  ...
# 8825  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 8826  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 8827  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 8828  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
# 8829  https://earthquake.usgs.gov/fdsnws/event/1/que...              NaN  ...
#
#                                     properties.types  properties.nst  \
# 0                  ,nearby-cities,origin,phase-data,            11.0
# 1                                ,origin,phase-data,             NaN
# 2                                ,origin,phase-data,             9.0
# 3     ,nearby-cities,origin,phase-data,scitech-link,            28.0
# 4     ,nearby-cities,origin,phase-data,scitech-link,            13.0
# ...                                              ...             ...
# 8825                             ,origin,phase-data,             4.0
# 8826  ,nearby-cities,origin,phase-data,scitech-link,            20.0
# 8827  ,nearby-cities,origin,phase-data,scitech-link,            21.0
# 8828                             ,origin,phase-data,            22.0
# 8829                             ,origin,phase-data,             NaN
#
#      properties.dmin properties.rms  properties.gap  properties.magType  \
# 0           0.002536         0.0200           87.00                  md
# 1                NaN         0.7100             NaN                  ml
# 2           0.082000         0.0799          163.30                  ml
# 3           0.076000         0.2300          113.00                  ml
# 4           0.097250         0.2200           89.00                  ml
# ...              ...            ...             ...                 ...
# 8825        0.279000         0.1401          257.63                  ml
# 8826        0.105900         0.1500           84.00                  ml
# 8827        0.043750         0.0800           83.00                  ml
# 8828        0.233100         0.1700           60.00                  ml
# 8829             NaN         0.4000             NaN                  ml
#
#      properties.type                        properties.title geometry.type  \
# 0         earthquake       M 0.8 - 5km NW of The Geysers, CA         Point
# 1         earthquake     M 1.4 - 47 km NNW of Valdez, Alaska         Point
# 2         earthquake         M 0.3 - 30 km S of Mina, Nevada         Point
# 3         earthquake            M 1.1 - 16km SW of Oasis, CA         Point
# 4         earthquake            M 0.8 - 15km SW of Oasis, CA         Point
# ...              ...                                     ...           ...
# 8825      earthquake     M 0.2 - 43 km WSW of Beatty, Nevada         Point
# 8826      earthquake  M 0.8 - 12km NNE of Ocotillo Wells, CA         Point
# 8827      earthquake             M 0.3 - 10km SW of Anza, CA         Point
# 8828      earthquake                            M 2.0 - Utah         Point
# 8829      earthquake   M 1.2 - 6 km W of Eagle River, Alaska         Point
#
#                    geometry.coordinates
# 0      [-122.7923355, 38.8089981, 1.04]
# 1            [-146.5832, 61.5426, 29.6]
# 2             [-118.0601, 38.1177, 8.2]
# 3      [-116.2188339, 33.3600006, 9.07]
# 4            [-116.194, 33.3525, 12.06]
# ...                                 ...
# 8825         [-117.1998, 36.7354, 15.2]
# 8826   [-116.0998333, 33.2451667, 9.21]
# 8827      [-116.7536667, 33.4925, 6.72]
# 8828  [-113.0571667, 37.8766667, 12.22]
# 8829         [-149.6931, 61.3193, 28.9]
#
# [8830 rows x 30 columns]

# %%
# getting the maximum of the feature properties.mag
earthquake_data['properties.mag'].max()
# Out:
# 7.0
